# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagajyothi41/AI-chatbot/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas import read_csv
path="/content/drive/MyDrive/rawdata.csv"
df=pd.read_csv(path)
new_def=df.dropna()
print(new_def.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        60.0  110.0     130.0     409.1
# 2        60.0  103.0     135.0     340.0
# 4        45.0  117.0     148.0     406.0
# 10       60.0  103.0     147.0     329.3
# 11       60.0  100.0     120.0     250.7
# 12       60.0  106.0     128.0     345.3
# 13       60.0  104.0     132.0     379.3
# 14       60.0   98.0     123.0     275.0
# 15       60.0   98.0     120.0     215.2
# 16       60.0  100.0     120.0     300.0
# 18       60.0  103.0     123.0     323.0
# 19       45.0   97.0     125.0     243.0
# 20       60.0  108.0     131.0     364.2
# 21       45.0  100.0     119.0     282.0
# 22       60.0  130.0     101.0     300.0
# 23       45.0  105.0     132.0     246.0
# 24       60.0  102.0     126.0     334.5
# 25       60.0  100.0     120.0     250.0
# 26       60.0   92.0     118.0     241.0
# 28       60.0  100.0     132.0     280.0
# 29       60.0  102.0     129.0     380.3
# 30       60.0   92.0     115.0     243.0
# ...

# %%
import pandas as pd
from pandas import read_csv
path="/content/drive/MyDrive/rawdata.csv"
df=pd.read_csv(path)
new_df=df.fillna(130)
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        60.0  110.0     130.0     409.1
# 1        60.0  130.0     145.0     479.0
# 2        60.0  103.0     135.0     340.0
# 3        45.0  109.0     130.0     282.4
# 4        45.0  117.0     148.0     406.0
# 5        60.0  102.0     127.0     130.0
# 6       130.0  110.0     136.0     374.0
# 7        45.0  130.0     134.0     253.3
# 8        30.0  109.0     130.0     195.1
# 9        60.0   98.0     124.0     130.0
# 10       60.0  103.0     147.0     329.3
# 11       60.0  100.0     120.0     250.7
# 12       60.0  106.0     128.0     345.3
# 13       60.0  104.0     132.0     379.3
# 14       60.0   98.0     123.0     275.0
# 15       60.0   98.0     120.0     215.2
# 16       60.0  100.0     120.0     300.0
# 17       45.0   90.0     112.0     130.0
# 18       60.0  103.0     123.0     323.0
# 19       45.0   97.0     125.0     243.0
# 20       60.0  108.0     131.0     364.2
# 21       45.0  100.0     119.0     282.0
# ...

# %%
#replace only for specific columns
new_df=df["Calories"].fillna(130);
print(new_df.to_string())
# Out:
# 0       409.1
# 1       479.0
# 2       340.0
# 3       282.4
# 4       406.0
# 5       130.0
# 6       374.0
# 7       253.3
# 8       195.1
# 9       130.0
# 10      329.3
# 11      250.7
# 12      345.3
# 13      379.3
# 14      275.0
# 15      215.2
# 16      300.0
# 17      130.0
# 18      323.0
# 19      243.0
# 20      364.2
# 21      282.0
# 22      300.0
# 23      246.0
# 24      334.5
# 25      250.0
# 26      241.0
# 27      130.0
# 28      280.0
# 29      380.3
# 30      243.0
# 31      180.1
# 32      299.0
# 33      223.0
# 34      361.0
# 35      415.0
# 36      300.0
# 37      300.0
# 38      300.0
# 39      266.0
# 40      180.1
# 41      286.0
# 42      329.4
# 43      400.0
# 44      397.0
# 45      273.0
# 46      387.6
# 47      300.0
# 48      298.0
# 49      397.6
# 50      380.2
# 51      643.1
# 52      263.0
# 53      486.0
# 54      238.0
# 55      450.7
# 56      413.0
# 57      305.0
# 58      226.4
# 59      321.0
# 60     1376.0
# 61     1034.4
# ...

# %%
new_df=df["Duration"].fillna(60);
print(new_df.to_string())
# Out:
# 0       60.0
# 1       60.0
# 2       60.0
# 3       45.0
# 4       45.0
# 5       60.0
# 6       60.0
# 7       45.0
# 8       30.0
# 9       60.0
# 10      60.0
# 11      60.0
# 12      60.0
# 13      60.0
# 14      60.0
# 15      60.0
# 16      60.0
# 17      45.0
# 18      60.0
# 19      45.0
# 20      60.0
# 21      45.0
# 22      60.0
# 23      45.0
# 24      60.0
# 25      60.0
# 26      60.0
# 27      60.0
# 28      60.0
# 29      60.0
# 30      60.0
# 31      45.0
# 32      60.0
# 33      60.0
# 34      60.0
# 35      60.0
# 36      60.0
# 37      60.0
# 38      60.0
# 39      45.0
# 40      45.0
# 41      60.0
# 42      60.0
# 43      60.0
# 44      60.0
# 45      60.0
# 46      60.0
# 47      45.0
# 48      45.0
# 49      60.0
# 50      60.0
# 51      80.0
# 52      60.0
# 53      60.0
# 54      30.0
# 55      60.0
# 56      60.0
# 57      45.0
# 58      20.0
# 59      45.0
# 60     210.0
# 61     160.0
# 62     160.0
# 63      45.0
# 64      20.0
# 65     180.0
# ...

# %%
#mean
x=df["Duration"].mean()
new_df=df["Duration"].fillna(x)
print(new_df.to_string())
# Out:
# 0       60.000000
# 1       60.000000
# 2       60.000000
# 3       45.000000
# 4       45.000000
# 5       60.000000
# 6       63.869048
# 7       45.000000
# 8       30.000000
# 9       60.000000
# 10      60.000000
# 11      60.000000
# 12      60.000000
# 13      60.000000
# 14      60.000000
# 15      60.000000
# 16      60.000000
# 17      45.000000
# 18      60.000000
# 19      45.000000
# 20      60.000000
# 21      45.000000
# 22      60.000000
# 23      45.000000
# 24      60.000000
# 25      60.000000
# 26      60.000000
# 27      60.000000
# 28      60.000000
# 29      60.000000
# 30      60.000000
# 31      45.000000
# 32      60.000000
# 33      60.000000
# 34      60.000000
# 35      60.000000
# 36      60.000000
# 37      60.000000
# 38      60.000000
# 39      45.000000
# 40      45.000000
# 41      60.000000
# 42      60.000000
# 43      60.000000
# 44      60.000000
# 45      60.000000
# 46      60.000000
# 47      45.000000
# 48      45.000000
# 49      60.000000
# ...

# %%
y=df["Pulse"].median()
new_df=df["Pulse"].fillna(y)
print(new_df.to_string())
# Out:
# 0      110.00000
# 1      107.42515
# 2      103.00000
# 3      109.00000
# 4      117.00000
# 5      102.00000
# 6      110.00000
# 7      107.42515
# 8      109.00000
# 9       98.00000
# 10     103.00000
# 11     100.00000
# 12     106.00000
# 13     104.00000
# 14      98.00000
# 15      98.00000
# 16     100.00000
# 17      90.00000
# 18     103.00000
# 19      97.00000
# 20     108.00000
# 21     100.00000
# 22     130.00000
# 23     105.00000
# 24     102.00000
# 25     100.00000
# 26      92.00000
# 27     103.00000
# 28     100.00000
# 29     102.00000
# 30      92.00000
# 31      90.00000
# 32     101.00000
# 33      93.00000
# 34     107.00000
# 35     114.00000
# 36     102.00000
# 37     100.00000
# 38     100.00000
# 39     104.00000
# 40      90.00000
# 41      98.00000
# 42     100.00000
# 43     111.00000
# 44     111.00000
# 45      99.00000
# 46     109.00000
# 47     111.00000
# 48     108.00000
# 49     111.00000
# 50     107.00000
# 51     123.00000
# ...

# %%
df.loc[7,"Duration"]=45
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        60.0  110.0     130.0     409.1
# 1        60.0    NaN     145.0     479.0
# 2        60.0  103.0     135.0     340.0
# 3        45.0  109.0       NaN     282.4
# 4        45.0  117.0     148.0     406.0
# 5        60.0  102.0     127.0       NaN
# 6         NaN  110.0     136.0     374.0
# 7        45.0    NaN     134.0     253.3
# 8        30.0  109.0       NaN     195.1
# 9        60.0   98.0     124.0       NaN
# 10       60.0  103.0     147.0     329.3
# 11       60.0  100.0     120.0     250.7
# 12       60.0  106.0     128.0     345.3
# 13       60.0  104.0     132.0     379.3
# 14       60.0   98.0     123.0     275.0
# 15       60.0   98.0     120.0     215.2
# 16       60.0  100.0     120.0     300.0
# 17       45.0   90.0     112.0       NaN
# 18       60.0  103.0     123.0     323.0
# 19       45.0   97.0     125.0     243.0
# 20       60.0  108.0     131.0     364.2
# 21       45.0  100.0     119.0     282.0
# ...

# %%
#fooling in including a value
for x in df.index:
  if df.loc[x,"Duration"]>120:
    df.loc[x,"duration"]=120
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories  duration
# 0        60.0  110.0     130.0     409.1       NaN
# 1        60.0    NaN     145.0     479.0       NaN
# 2        60.0  103.0     135.0     340.0       NaN
# 3        45.0  109.0       NaN     282.4       NaN
# 4        45.0  117.0     148.0     406.0       NaN
# 5        60.0  102.0     127.0       NaN       NaN
# 6         NaN  110.0     136.0     374.0       NaN
# 7        45.0    NaN     134.0     253.3       NaN
# 8        30.0  109.0       NaN     195.1       NaN
# 9        60.0   98.0     124.0       NaN       NaN
# 10       60.0  103.0     147.0     329.3       NaN
# 11       60.0  100.0     120.0     250.7       NaN
# 12       60.0  106.0     128.0     345.3       NaN
# 13       60.0  104.0     132.0     379.3       NaN
# 14       60.0   98.0     123.0     275.0       NaN
# 15       60.0   98.0     120.0     215.2       NaN
# 16       60.0  100.0     120.0     300.0       NaN
# ...

# %%
z=df["Maxpulse"].mode()[0]
new_df=df["Maxpulse"].fillna(z)
print(new_df.to_string())
# Out:
# 0      130.0
# 1      145.0
# 2      135.0
# 3      120.0
# 4      148.0
# 5      127.0
# 6      136.0
# 7      134.0
# 8      120.0
# 9      124.0
# 10     147.0
# 11     120.0
# 12     128.0
# 13     132.0
# 14     123.0
# 15     120.0
# 16     120.0
# 17     112.0
# 18     123.0
# 19     125.0
# 20     131.0
# 21     119.0
# 22     101.0
# 23     132.0
# 24     126.0
# 25     120.0
# 26     118.0
# 27     132.0
# 28     132.0
# 29     129.0
# 30     115.0
# 31     112.0
# 32     124.0
# 33     113.0
# 34     136.0
# 35     140.0
# 36     127.0
# 37     120.0
# 38     120.0
# 39     129.0
# 40     112.0
# 41     126.0
# 42     122.0
# 43     138.0
# 44     131.0
# 45     119.0
# 46     153.0
# 47     136.0
# 48     129.0
# 49     139.0
# 50     136.0
# 51     146.0
# 52     130.0
# 53     151.0
# 54     175.0
# 55     146.0
# 56     121.0
# 57     144.0
# 58     172.0
# 59     152.0
# 60     160.0
# 61     137.0
# 62     135.0
# 63     141.0
# 64     130.0
# 65     130.0
# ...
